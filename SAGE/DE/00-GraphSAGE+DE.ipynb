# %%
import torch
import torch_geometric

train_data = torch.load('train_data.pt')
val_data = torch.load('val_data.pt')
test_data = torch.load('test_data.pt')

# %%
from sklearn.metrics import roc_auc_score, average_precision_score, recall_score
from scipy.sparse.csgraph import shortest_path

import torch.nn.functional as F
from torch.nn import Conv1d, MaxPool1d, Linear, Dropout, BCEWithLogitsLoss, GRU

from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import RandomLinkSplit
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, aggr, global_sort_pool
from torch_geometric.utils import k_hop_subgraph, to_scipy_sparse_matrix

# %%
from torch_geometric.data import Data
import numpy as np
import torch
from torch.nn import functional as F
from scipy.sparse.csgraph import shortest_path
from torch_geometric.utils import k_hop_subgraph, to_scipy_sparse_matrix

def seal_processing(dataset, edge_label_index, y, max_dist=6):
    data_list = []
    for src, dst in edge_label_index.t().tolist():
        # 提取子图
        sub_nodes, sub_edge_index, mapping, _ = k_hop_subgraph([src, dst], 2, dataset.edge_index, relabel_nodes=True)
        src, dst = mapping.tolist()

        # 从子图中移除目标边
        mask1 = (sub_edge_index[0] != src) | (sub_edge_index[1] != dst)
        mask2 = (sub_edge_index[0] != dst) | (sub_edge_index[1] != src)
        sub_edge_index = sub_edge_index[:, mask1 & mask2]

        # 确保 src < dst
        src, dst = (dst, src) if src > dst else (src, dst)

        # 计算邻接矩阵
        adj = to_scipy_sparse_matrix(sub_edge_index, num_nodes=sub_nodes.size(0)).tocsr()

        # 计算距离编码
        dist = shortest_path(adj, directed=False, unweighted=True, indices=[src, dst])
        dist = torch.from_numpy(dist).to(torch.long)

        # 处理距离编码
        dist[dist > max_dist] = max_dist
        dist[torch.isnan(dist)] = max_dist + 1

        # 将距离转置以匹配预期的形状 (num_nodes, 2)
        dist = dist.t()

        # 对每一个距离进行 one-hot 编码
        node_labels_src = F.one_hot(dist[:, 0], num_classes=max_dist + 2).to(torch.float)
        node_labels_dst = F.one_hot(dist[:, 1], num_classes=max_dist + 2).to(torch.float)

        # 将两个 one-hot 编码的结果拼接起来
        node_labels = torch.cat([node_labels_src, node_labels_dst], dim=1)

        # 获取子图中的节点特征
        node_emb = dataset.x[sub_nodes]
        
        # 拼接节点特征和距离标签
        node_x = torch.cat([node_emb, node_labels], dim=1)

        # 创建数据对象
        data = Data(x=node_x, z=dist, edge_index=sub_edge_index, y=y)
        data_list.append(data)

    return data_list

# %%
# Enclosing subgraphs extraction
train_pos_data_list = seal_processing(train_data, train_data.pos_edge_label_index, 1)
train_neg_data_list = seal_processing(train_data, train_data.neg_edge_label_index, 0)

# %%
val_pos_data_list = seal_processing(val_data, val_data.pos_edge_label_index, 1)
val_neg_data_list = seal_processing(val_data, val_data.neg_edge_label_index, 0)

# %%
test_pos_data_list = seal_processing(test_data, test_data.pos_edge_label_index, 1)
test_neg_data_list = seal_processing(test_data, test_data.neg_edge_label_index, 0)

# %%
train_dataset = train_pos_data_list + train_neg_data_list
val_dataset = val_pos_data_list + val_neg_data_list
test_dataset = test_pos_data_list + test_neg_data_list

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv
class GraphSAGE(torch.nn.Module):
    def __init__(self, dim_in):
        super(GraphSAGE, self).__init__()
        # GCN layers
        self.gcn1 = SAGEConv(dim_in, 32)
        self.gcn2 = SAGEConv(32, 32)
        self.gcn3 = SAGEConv(32, 32)
        self.gcn4 = SAGEConv(32, 1)

        self.lin1 = Linear(97, dim_in)
        self.lin2 = Linear(dim_in, 1)

    def forward(self, x, edge_index, batch):
        x1 = self.gcn1(x, edge_index).tanh()
        x2 = self.gcn2(x1, edge_index).tanh()
        x3 = self.gcn3(x2, edge_index).tanh()
        x4 = self.gcn4(x3, edge_index).tanh()
        x = torch.cat([x1, x2, x3, x4], dim=-1)

        _, center_indices = np.unique(batch.cpu().numpy(), return_index=True)
        x_src = x[center_indices]
        x_dst = x[center_indices + 1]
        x = (x_src * x_dst)
        x = F.relu(self.lin1(x))
        x = self.lin2(x)

        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GraphSAGE(train_dataset[0].num_features).to(device)
optimizer = torch.optim.Adam(params=model.parameters(), lr=0.01)
criterion = BCEWithLogitsLoss()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def train():
    model.train()
    total_loss = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out.view(-1), data.y.to(torch.float))
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs

    return total_loss / len(train_dataset)

@torch.no_grad()
def test(loader):
    model.eval()
    y_pred, y_true = [], []

    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)
        y_pred.append(out.view(-1).cpu())
        y_true.append(data.y.view(-1).cpu().to(torch.float))

    y_pred_binary = (torch.cat(y_pred) > 0.5).numpy()
    y_true_array = torch.cat(y_true).numpy()

    auc = roc_auc_score(y_true_array, torch.cat(y_pred))
    accuracy = accuracy_score(y_true_array, y_pred_binary)
    f1 = f1_score(y_true_array, y_pred_binary)
    precision = precision_score(y_true_array, y_pred_binary)
    recall = recall_score(y_true_array, y_pred_binary)

    return auc, accuracy, f1, precision, recall

# %%
import matplotlib.pyplot as plt
train_loss = []
for epoch in range(300):
    loss = train()
    val_results = test(val_loader)
    val_auc, val_accuracy, val_f1, val_precision, val_recall = val_results
    print(f'Epoch {epoch:>2} | Loss: {loss:.4f} | Val AUC: {val_auc:.4f} ')
    train_loss.append(loss)

test_results = test(test_loader)
test_auc, test_accuracy, test_f1, test_precision, test_recall = test_results 
print(f'Test AUC: {test_auc:.4f} | Test Accuracy: {test_accuracy:.4f} | Test F1: {test_f1:.4f} | Test Precision: {test_precision:.4f} | Test Recall: {test_recall:.4f}')
# Out:
# Epoch  0 | Loss: 0.2883 | Val AUC: 0.8116
# Epoch  1 | Loss: 0.2499 | Val AUC: 0.8145
# Epoch  2 | Loss: 0.2340 | Val AUC: 0.8266
# Epoch  3 | Loss: 0.2231 | Val AUC: 0.8385
# Epoch  4 | Loss: 0.2166 | Val AUC: 0.8303
# Epoch  5 | Loss: 0.2102 | Val AUC: 0.8345
# Epoch  6 | Loss: 0.2025 | Val AUC: 0.8393
# Epoch  7 | Loss: 0.2002 | Val AUC: 0.8413
# Epoch  8 | Loss: 0.1974 | Val AUC: 0.8387
# Epoch  9 | Loss: 0.1925 | Val AUC: 0.8408
# Epoch 10 | Loss: 0.1854 | Val AUC: 0.8393
# Epoch 11 | Loss: 0.1844 | Val AUC: 0.8289
# Epoch 12 | Loss: 0.1852 | Val AUC: 0.8389
# Epoch 13 | Loss: 0.1824 | Val AUC: 0.8425
# Epoch 14 | Loss: 0.1795 | Val AUC: 0.8393
# Epoch 15 | Loss: 0.1751 | Val AUC: 0.8391
# Epoch 16 | Loss: 0.1742 | Val AUC: 0.8357
# Epoch 17 | Loss: 0.1714 | Val AUC: 0.8352
# Epoch 18 | Loss: 0.1723 | Val AUC: 0.8397
# Epoch 19 | Loss: 0.1683 | Val AUC: 0.8402
# Epoch 20 | Loss: 0.1670 | Val AUC: 0.8395
# Epoch 21 | Loss: 0.1724 | Val AUC: 0.8332
# Epoch 22 | Loss: 0.1709 | Val AUC: 0.8394
# Epoch 23 | Loss: 0.1645 | Val AUC: 0.8398
# Epoch 24 | Loss: 0.1631 | Val AUC: 0.8360
# Epoch 25 | Loss: 0.1632 | Val AUC: 0.8384
# Epoch 26 | Loss: 0.1601 | Val AUC: 0.8350
# Epoch 27 | Loss: 0.1575 | Val AUC: 0.8367
# Epoch 28 | Loss: 0.1560 | Val AUC: 0.8340
# Epoch 29 | Loss: 0.1562 | Val AUC: 0.8364
# Epoch 30 | Loss: 0.1618 | Val AUC: 0.8382
# Epoch 31 | Loss: 0.1574 | Val AUC: 0.8363
# Epoch 32 | Loss: 0.1532 | Val AUC: 0.8372
# Epoch 33 | Loss: 0.1530 | Val AUC: 0.8360
# Epoch 34 | Loss: 0.1526 | Val AUC: 0.8337
# Epoch 35 | Loss: 0.1519 | Val AUC: 0.8389
# Epoch 36 | Loss: 0.1518 | Val AUC: 0.8376
# Epoch 37 | Loss: 0.1510 | Val AUC: 0.8347
# Epoch 38 | Loss: 0.1482 | Val AUC: 0.8320
# Epoch 39 | Loss: 0.1471 | Val AUC: 0.8354
# Epoch 40 | Loss: 0.1464 | Val AUC: 0.8351
# Epoch 41 | Loss: 0.1500 | Val AUC: 0.8353
# Epoch 42 | Loss: 0.1463 | Val AUC: 0.8346
# Epoch 43 | Loss: 0.1485 | Val AUC: 0.8375
# Epoch 44 | Loss: 0.1475 | Val AUC: 0.8306
# Epoch 45 | Loss: 0.1449 | Val AUC: 0.8340
# Epoch 46 | Loss: 0.1444 | Val AUC: 0.8356
# Epoch 47 | Loss: 0.1403 | Val AUC: 0.8344
# Epoch 48 | Loss: 0.1467 | Val AUC: 0.8358
# Epoch 49 | Loss: 0.1445 | Val AUC: 0.8329
# Epoch 50 | Loss: 0.1432 | Val AUC: 0.8340
# Epoch 51 | Loss: 0.1435 | Val AUC: 0.8364
# Epoch 52 | Loss: 0.1407 | Val AUC: 0.8358
# Epoch 53 | Loss: 0.1417 | Val AUC: 0.8350
# Epoch 54 | Loss: 0.1413 | Val AUC: 0.8359
# Epoch 55 | Loss: 0.1397 | Val AUC: 0.8359
# Epoch 56 | Loss: 0.1404 | Val AUC: 0.8308
# Epoch 57 | Loss: 0.1453 | Val AUC: 0.8265
# Epoch 58 | Loss: 0.1400 | Val AUC: 0.8358
# Epoch 59 | Loss: 0.1389 | Val AUC: 0.8364
# Epoch 60 | Loss: 0.1361 | Val AUC: 0.8357
# Epoch 61 | Loss: 0.1349 | Val AUC: 0.8328
# Epoch 62 | Loss: 0.1439 | Val AUC: 0.8317
# Epoch 63 | Loss: 0.1374 | Val AUC: 0.8326
# Epoch 64 | Loss: 0.1416 | Val AUC: 0.8338
# Epoch 65 | Loss: 0.1392 | Val AUC: 0.8332
# Epoch 66 | Loss: 0.1424 | Val AUC: 0.8324
# Epoch 67 | Loss: 0.1360 | Val AUC: 0.8326
# Epoch 68 | Loss: 0.1369 | Val AUC: 0.8291
# Epoch 69 | Loss: 0.1355 | Val AUC: 0.8303
# Epoch 70 | Loss: 0.1341 | Val AUC: 0.8351
# Epoch 71 | Loss: 0.1349 | Val AUC: 0.8337
# Epoch 72 | Loss: 0.1340 | Val AUC: 0.8341
# Epoch 73 | Loss: 0.1339 | Val AUC: 0.8356
# Epoch 74 | Loss: 0.1344 | Val AUC: 0.8348
# Epoch 75 | Loss: 0.1311 | Val AUC: 0.8345
# Epoch 76 | Loss: 0.1355 | Val AUC: 0.8265
# Epoch 77 | Loss: 0.1325 | Val AUC: 0.8295
# Epoch 78 | Loss: 0.1334 | Val AUC: 0.8326
# Epoch 79 | Loss: 0.1276 | Val AUC: 0.8344
# Epoch 80 | Loss: 0.1296 | Val AUC: 0.8328
# Epoch 81 | Loss: 0.1298 | Val AUC: 0.8328
# Epoch 82 | Loss: 0.1359 | Val AUC: 0.8357
# Epoch 83 | Loss: 0.1327 | Val AUC: 0.8332
# Epoch 84 | Loss: 0.1288 | Val AUC: 0.8358
# Epoch 85 | Loss: 0.1323 | Val AUC: 0.8299
# Epoch 86 | Loss: 0.1298 | Val AUC: 0.8319
# Epoch 87 | Loss: 0.1262 | Val AUC: 0.8318
# Epoch 88 | Loss: 0.1272 | Val AUC: 0.8308
# Epoch 89 | Loss: 0.1289 | Val AUC: 0.8300
# Epoch 90 | Loss: 0.1300 | Val AUC: 0.8307
# Epoch 91 | Loss: 0.1309 | Val AUC: 0.8303
# Epoch 92 | Loss: 0.1280 | Val AUC: 0.8310
# Epoch 93 | Loss: 0.1289 | Val AUC: 0.8334
# Epoch 94 | Loss: 0.1291 | Val AUC: 0.8306
# Epoch 95 | Loss: 0.1255 | Val AUC: 0.8270
# Epoch 96 | Loss: 0.1278 | Val AUC: 0.8280
# Epoch 97 | Loss: 0.1261 | Val AUC: 0.8325
# Epoch 98 | Loss: 0.1250 | Val AUC: 0.8330
# Epoch 99 | Loss: 0.1253 | Val AUC: 0.8314
# Epoch 100 | Loss: 0.1275 | Val AUC: 0.8292
# Epoch 101 | Loss: 0.1282 | Val AUC: 0.8307
# Epoch 102 | Loss: 0.1423 | Val AUC: 0.8254
# Epoch 103 | Loss: 0.1337 | Val AUC: 0.8290
# Epoch 104 | Loss: 0.1278 | Val AUC: 0.8303
# Epoch 105 | Loss: 0.1298 | Val AUC: 0.8304
# Epoch 106 | Loss: 0.1241 | Val AUC: 0.8274
# Epoch 107 | Loss: 0.1233 | Val AUC: 0.8272
# Epoch 108 | Loss: 0.1254 | Val AUC: 0.8275
# Epoch 109 | Loss: 0.1252 | Val AUC: 0.8293
# Epoch 110 | Loss: 0.1267 | Val AUC: 0.8286
# Epoch 111 | Loss: 0.1280 | Val AUC: 0.8298
# Epoch 112 | Loss: 0.1284 | Val AUC: 0.8303
# Epoch 113 | Loss: 0.1306 | Val AUC: 0.8271
# Epoch 114 | Loss: 0.1303 | Val AUC: 0.8278
# Epoch 115 | Loss: 0.1224 | Val AUC: 0.8262
# Epoch 116 | Loss: 0.1358 | Val AUC: 0.8243
# Epoch 117 | Loss: 0.1265 | Val AUC: 0.8244
# Epoch 118 | Loss: 0.1237 | Val AUC: 0.8274
# Epoch 119 | Loss: 0.1240 | Val AUC: 0.8287
# Epoch 120 | Loss: 0.1221 | Val AUC: 0.8243
# Epoch 121 | Loss: 0.1226 | Val AUC: 0.8218
# Epoch 122 | Loss: 0.1258 | Val AUC: 0.8287
# Epoch 123 | Loss: 0.1269 | Val AUC: 0.8254
# Epoch 124 | Loss: 0.1306 | Val AUC: 0.8294
# Epoch 125 | Loss: 0.1246 | Val AUC: 0.8273
# Epoch 126 | Loss: 0.1194 | Val AUC: 0.8281
# Epoch 127 | Loss: 0.1245 | Val AUC: 0.8285
# Epoch 128 | Loss: 0.1232 | Val AUC: 0.8271
# Epoch 129 | Loss: 0.1210 | Val AUC: 0.8280
# Epoch 130 | Loss: 0.1256 | Val AUC: 0.8237
# Epoch 131 | Loss: 0.1279 | Val AUC: 0.8293
# Epoch 132 | Loss: 0.1237 | Val AUC: 0.8275
# Epoch 133 | Loss: 0.1213 | Val AUC: 0.8277
# Epoch 134 | Loss: 0.1232 | Val AUC: 0.8270
# Epoch 135 | Loss: 0.1193 | Val AUC: 0.8252
# Epoch 136 | Loss: 0.1211 | Val AUC: 0.8273
# Epoch 137 | Loss: 0.1253 | Val AUC: 0.8257
# Epoch 138 | Loss: 0.1237 | Val AUC: 0.8276
# Epoch 139 | Loss: 0.1276 | Val AUC: 0.8238
# Epoch 140 | Loss: 0.1249 | Val AUC: 0.8297
# Epoch 141 | Loss: 0.1308 | Val AUC: 0.8289
# Epoch 142 | Loss: 0.1287 | Val AUC: 0.8287
# Epoch 143 | Loss: 0.1328 | Val AUC: 0.8301
# Epoch 144 | Loss: 0.1209 | Val AUC: 0.8276
# Epoch 145 | Loss: 0.1281 | Val AUC: 0.8320
# Epoch 146 | Loss: 0.1250 | Val AUC: 0.8275
# Epoch 147 | Loss: 0.1223 | Val AUC: 0.8283
# Epoch 148 | Loss: 0.1183 | Val AUC: 0.8281
# Epoch 149 | Loss: 0.1193 | Val AUC: 0.8288
# Epoch 150 | Loss: 0.1202 | Val AUC: 0.8278
# Epoch 151 | Loss: 0.1221 | Val AUC: 0.8284
# Epoch 152 | Loss: 0.1213 | Val AUC: 0.8277
# Epoch 153 | Loss: 0.1200 | Val AUC: 0.8257
# Epoch 154 | Loss: 0.1228 | Val AUC: 0.8238
# Epoch 155 | Loss: 0.1216 | Val AUC: 0.8262
# Epoch 156 | Loss: 0.1191 | Val AUC: 0.8259
# Epoch 157 | Loss: 0.1284 | Val AUC: 0.8239
# Epoch 158 | Loss: 0.1224 | Val AUC: 0.8277
# Epoch 159 | Loss: 0.1237 | Val AUC: 0.8244
# Epoch 160 | Loss: 0.1211 | Val AUC: 0.8243
# Epoch 161 | Loss: 0.1171 | Val AUC: 0.8274
# Epoch 162 | Loss: 0.1212 | Val AUC: 0.8261
# Epoch 163 | Loss: 0.1169 | Val AUC: 0.8281
# Epoch 164 | Loss: 0.1137 | Val AUC: 0.8267
# Epoch 165 | Loss: 0.1156 | Val AUC: 0.8270
# Epoch 166 | Loss: 0.1160 | Val AUC: 0.8230
# Epoch 167 | Loss: 0.1193 | Val AUC: 0.8234
# Epoch 168 | Loss: 0.1157 | Val AUC: 0.8256
# Epoch 169 | Loss: 0.1187 | Val AUC: 0.8268
# Epoch 170 | Loss: 0.1232 | Val AUC: 0.8259
# Epoch 171 | Loss: 0.1199 | Val AUC: 0.8264
# Epoch 172 | Loss: 0.1171 | Val AUC: 0.8267
# Epoch 173 | Loss: 0.1160 | Val AUC: 0.8277
# Epoch 174 | Loss: 0.1173 | Val AUC: 0.8285
# Epoch 175 | Loss: 0.1201 | Val AUC: 0.8247
# Epoch 176 | Loss: 0.1203 | Val AUC: 0.8270
# Epoch 177 | Loss: 0.1233 | Val AUC: 0.8268
# Epoch 178 | Loss: 0.1148 | Val AUC: 0.8269
# Epoch 179 | Loss: 0.1177 | Val AUC: 0.8233
# Epoch 180 | Loss: 0.1177 | Val AUC: 0.8285
# Epoch 181 | Loss: 0.1181 | Val AUC: 0.8265
# Epoch 182 | Loss: 0.1181 | Val AUC: 0.8272
# Epoch 183 | Loss: 0.1169 | Val AUC: 0.8281
# Epoch 184 | Loss: 0.1228 | Val AUC: 0.8270
# Epoch 185 | Loss: 0.1141 | Val AUC: 0.8278
# Epoch 186 | Loss: 0.1115 | Val AUC: 0.8276
# Epoch 187 | Loss: 0.1163 | Val AUC: 0.8290
# Epoch 188 | Loss: 0.1157 | Val AUC: 0.8282
# Epoch 189 | Loss: 0.1169 | Val AUC: 0.8264
# Epoch 190 | Loss: 0.1149 | Val AUC: 0.8233
# Epoch 191 | Loss: 0.1178 | Val AUC: 0.8248
# Epoch 192 | Loss: 0.1146 | Val AUC: 0.8260
# Epoch 193 | Loss: 0.1142 | Val AUC: 0.8251
# Epoch 194 | Loss: 0.1211 | Val AUC: 0.8238
# Epoch 195 | Loss: 0.1288 | Val AUC: 0.8266
# Epoch 196 | Loss: 0.1225 | Val AUC: 0.8251
# Epoch 197 | Loss: 0.1151 | Val AUC: 0.8288
# Epoch 198 | Loss: 0.1123 | Val AUC: 0.8314
# Epoch 199 | Loss: 0.1096 | Val AUC: 0.8300
# Epoch 200 | Loss: 0.1158 | Val AUC: 0.8282
# Epoch 201 | Loss: 0.1131 | Val AUC: 0.8288
# Epoch 202 | Loss: 0.1138 | Val AUC: 0.8292
# Epoch 203 | Loss: 0.1133 | Val AUC: 0.8240
# Epoch 204 | Loss: 0.1131 | Val AUC: 0.8261
# Epoch 205 | Loss: 0.1148 | Val AUC: 0.8258
# Epoch 206 | Loss: 0.1147 | Val AUC: 0.8264
# Epoch 207 | Loss: 0.1133 | Val AUC: 0.8255
# Epoch 208 | Loss: 0.1118 | Val AUC: 0.8282
# Epoch 209 | Loss: 0.1130 | Val AUC: 0.8279
# Epoch 210 | Loss: 0.1195 | Val AUC: 0.8274
# Epoch 211 | Loss: 0.1142 | Val AUC: 0.8281
# Epoch 212 | Loss: 0.1120 | Val AUC: 0.8278
# Epoch 213 | Loss: 0.1086 | Val AUC: 0.8282
# Epoch 214 | Loss: 0.1100 | Val AUC: 0.8253
# Epoch 215 | Loss: 0.1100 | Val AUC: 0.8267
# Epoch 216 | Loss: 0.1111 | Val AUC: 0.8263
# Epoch 217 | Loss: 0.1225 | Val AUC: 0.8249
# Epoch 218 | Loss: 0.1289 | Val AUC: 0.8257
# Epoch 219 | Loss: 0.1229 | Val AUC: 0.8236
# Epoch 220 | Loss: 0.1115 | Val AUC: 0.8259
# Epoch 221 | Loss: 0.1109 | Val AUC: 0.8266
# Epoch 222 | Loss: 0.1057 | Val AUC: 0.8262
# Epoch 223 | Loss: 0.1116 | Val AUC: 0.8241
# Epoch 224 | Loss: 0.1128 | Val AUC: 0.8250
# Epoch 225 | Loss: 0.1126 | Val AUC: 0.8248
# Epoch 226 | Loss: 0.1120 | Val AUC: 0.8251
# Epoch 227 | Loss: 0.1167 | Val AUC: 0.8230
# Epoch 228 | Loss: 0.1176 | Val AUC: 0.8262
# Epoch 229 | Loss: 0.1174 | Val AUC: 0.8222
# Epoch 230 | Loss: 0.1144 | Val AUC: 0.8292
# Epoch 231 | Loss: 0.1113 | Val AUC: 0.8271
# Epoch 232 | Loss: 0.1113 | Val AUC: 0.8261
# Epoch 233 | Loss: 0.1323 | Val AUC: 0.8254
# Epoch 234 | Loss: 0.1214 | Val AUC: 0.8249
# Epoch 235 | Loss: 0.1153 | Val AUC: 0.8272
# Epoch 236 | Loss: 0.1176 | Val AUC: 0.8249
# Epoch 237 | Loss: 0.1229 | Val AUC: 0.8273
# Epoch 238 | Loss: 0.1164 | Val AUC: 0.8291
# Epoch 239 | Loss: 0.1146 | Val AUC: 0.8247
# Epoch 240 | Loss: 0.1153 | Val AUC: 0.8254
# Epoch 241 | Loss: 0.1161 | Val AUC: 0.8221
# Epoch 242 | Loss: 0.1153 | Val AUC: 0.8238
# Epoch 243 | Loss: 0.1164 | Val AUC: 0.8212
# Epoch 244 | Loss: 0.1117 | Val AUC: 0.8238
# Epoch 245 | Loss: 0.1072 | Val AUC: 0.8196
# Epoch 246 | Loss: 0.1117 | Val AUC: 0.8189
# Epoch 247 | Loss: 0.1166 | Val AUC: 0.8196
# Epoch 248 | Loss: 0.1137 | Val AUC: 0.8187
# Epoch 249 | Loss: 0.1135 | Val AUC: 0.8232
# Epoch 250 | Loss: 0.1141 | Val AUC: 0.8238
# Epoch 251 | Loss: 0.1153 | Val AUC: 0.8241
# Epoch 252 | Loss: 0.1148 | Val AUC: 0.8229
# Epoch 253 | Loss: 0.1093 | Val AUC: 0.8240
# Epoch 254 | Loss: 0.1108 | Val AUC: 0.8213
# Epoch 255 | Loss: 0.1123 | Val AUC: 0.8234
# Epoch 256 | Loss: 0.1201 | Val AUC: 0.8253
# Epoch 257 | Loss: 0.1150 | Val AUC: 0.8235
# Epoch 258 | Loss: 0.1089 | Val AUC: 0.8225
# Epoch 259 | Loss: 0.1120 | Val AUC: 0.8253
# Epoch 260 | Loss: 0.1101 | Val AUC: 0.8227
# Epoch 261 | Loss: 0.1108 | Val AUC: 0.8204
# Epoch 262 | Loss: 0.1076 | Val AUC: 0.8223
# Epoch 263 | Loss: 0.1112 | Val AUC: 0.8226
# Epoch 264 | Loss: 0.1116 | Val AUC: 0.8217
# Epoch 265 | Loss: 0.1089 | Val AUC: 0.8208
# Epoch 266 | Loss: 0.1076 | Val AUC: 0.8199
# Epoch 267 | Loss: 0.1131 | Val AUC: 0.8187
# Epoch 268 | Loss: 0.1168 | Val AUC: 0.8227
# Epoch 269 | Loss: 0.1108 | Val AUC: 0.8200
# Epoch 270 | Loss: 0.1131 | Val AUC: 0.8216
# Epoch 271 | Loss: 0.1101 | Val AUC: 0.8229
# Epoch 272 | Loss: 0.1097 | Val AUC: 0.8229
# Epoch 273 | Loss: 0.1132 | Val AUC: 0.8232
# Epoch 274 | Loss: 0.1085 | Val AUC: 0.8233
# Epoch 275 | Loss: 0.1094 | Val AUC: 0.8207
# Epoch 276 | Loss: 0.1068 | Val AUC: 0.8233
# Epoch 277 | Loss: 0.1095 | Val AUC: 0.8233
# Epoch 278 | Loss: 0.1150 | Val AUC: 0.8210
# Epoch 279 | Loss: 0.1302 | Val AUC: 0.8222
# Epoch 280 | Loss: 0.1129 | Val AUC: 0.8239
# Epoch 281 | Loss: 0.1121 | Val AUC: 0.8280
# Epoch 282 | Loss: 0.1084 | Val AUC: 0.8255
# Epoch 283 | Loss: 0.1098 | Val AUC: 0.8209
# Epoch 284 | Loss: 0.1118 | Val AUC: 0.8252
# Epoch 285 | Loss: 0.1056 | Val AUC: 0.8250
# Epoch 286 | Loss: 0.1080 | Val AUC: 0.8256
# Epoch 287 | Loss: 0.1092 | Val AUC: 0.8269
# Epoch 288 | Loss: 0.1098 | Val AUC: 0.8245
# Epoch 289 | Loss: 0.1222 | Val AUC: 0.8262
# Epoch 290 | Loss: 0.1118 | Val AUC: 0.8240
# Epoch 291 | Loss: 0.1095 | Val AUC: 0.8241
# Epoch 292 | Loss: 0.1097 | Val AUC: 0.8214
# Epoch 293 | Loss: 0.1127 | Val AUC: 0.8229
# Epoch 294 | Loss: 0.1163 | Val AUC: 0.8221
# Epoch 295 | Loss: 0.1126 | Val AUC: 0.8217
# Epoch 296 | Loss: 0.1101 | Val AUC: 0.8214
# Epoch 297 | Loss: 0.1070 | Val AUC: 0.8234
# Epoch 298 | Loss: 0.1065 | Val AUC: 0.8213
# Epoch 299 | Loss: 0.1046 | Val AUC: 0.8234
# Test AUC: 0.7748 | Test Accuracy: 0.7161 | Test F1: 0.7078 | Test Precision: 0.7291 | Test Recall: 0.6876
